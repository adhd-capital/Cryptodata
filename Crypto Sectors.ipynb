# %%
from pycoingecko import CoinGeckoAPI
cg = CoinGeckoAPI()

def get_sectors():
    categories = cg.get_coins_categories_list()
    return categories

sectors = get_sectors()
print(sectors[:20])
# Out:
# [{'category_id': 'aave-tokens', 'name': 'Aave Tokens'}, {'category_id': 'account-abstraction', 'name': 'Account Abstraction'}, {'category_id': 'adidas-ecosystem', 'name': 'Adidas Ecosystem'}, {'category_id': 'adventure-games', 'name': 'Adventure Games'}, {'category_id': 'ai-agents', 'name': 'AI Agents'}, {'category_id': 'ai-meme-coins', 'name': 'AI Meme Coins'}, {'category_id': 'ai-themed-coins', 'name': 'AI-Themed Coins'}, {'category_id': 'alephium-ecosystem', 'name': 'Alephium Ecosystem'}, {'category_id': 'algorand-ecosystem', 'name': 'Algorand Ecosystem'}, {'category_id': 'alleged-sec-securities', 'name': 'Alleged SEC Securities'}, {'category_id': 'analytics', 'name': 'Analytics'}, {'category_id': 'animal-racing', 'name': 'Animal Racing'}, {'category_id': 'anime-themed-coins', 'name': 'Anime-Themed Coins'}, {'category_id': 'animoca-brands', 'name': 'Animoca Brands'}, {'category_id': 'apex-chain-ecosystem', 'name': 'Apex Chain Ecosystem'}, {'category_id': 'aptos-ecosystem', 'name':
# ...

# %%
sectors
# Out:
# [{'category_id': 'aave-tokens', 'name': 'Aave Tokens'},
#  {'category_id': 'account-abstraction', 'name': 'Account Abstraction'},
#  {'category_id': 'adidas-ecosystem', 'name': 'Adidas Ecosystem'},
#  {'category_id': 'adventure-games', 'name': 'Adventure Games'},
#  {'category_id': 'ai-agents', 'name': 'AI Agents'},
#  {'category_id': 'ai-meme-coins', 'name': 'AI Meme Coins'},
#  {'category_id': 'ai-themed-coins', 'name': 'AI-Themed Coins'},
#  {'category_id': 'alephium-ecosystem', 'name': 'Alephium Ecosystem'},
#  {'category_id': 'algorand-ecosystem', 'name': 'Algorand Ecosystem'},
#  {'category_id': 'alleged-sec-securities', 'name': 'Alleged SEC Securities'},
#  {'category_id': 'analytics', 'name': 'Analytics'},
#  {'category_id': 'animal-racing', 'name': 'Animal Racing'},
#  {'category_id': 'anime-themed-coins', 'name': 'Anime-Themed Coins'},
#  {'category_id': 'animoca-brands', 'name': 'Animoca Brands'},
#  {'category_id': 'apex-chain-ecosystem', 'name': 'Apex Chain Ecosystem'},
# ...
